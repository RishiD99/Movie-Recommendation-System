# %%
import numpy as np
import pandas as pd

# %%
movies_df = pd.read_csv(r"C:\Users\ditri\Desktop\Important\Data\Movie Lens Data\ml-latest-small\movies.csv")

# %%
weighted_ratings = pd.read_csv(r"C:\Users\ditri\Desktop\Important\Data\Movie Lens Data\ml-latest-small\movie_ratings_weighted.csv")

# %%
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
pattern = r"\((\d{4})\)"
movies_df['release_year'] = movies_df['title'].str.extract(pattern)

movies_df = movies_df.dropna(subset = 'release_year').copy()

movies_df['release_year'] = movies_df['release_year'].astype(np.int16)

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  release_year
# 0  Adventure|Animation|Children|Comedy|Fantasy          1995
# 1                   Adventure|Children|Fantasy          1995
# 2                               Comedy|Romance          1995
# 3                         Comedy|Drama|Romance          1995
# 4                                       Comedy          1995

# %%
movies_df['genres'] = movies_df['genres'] + '|'
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                          genres  release_year
# 0  Adventure|Animation|Children|Comedy|Fantasy|          1995
# 1                   Adventure|Children|Fantasy|          1995
# 2                               Comedy|Romance|          1995
# 3                         Comedy|Drama|Romance|          1995
# 4                                       Comedy|          1995

# %%
s = movies_df['genres'].sum()

# %%
unique_genre = set(s.split('|'))
print(unique_genre)
# Out:
# {'', 'Drama', 'Sci-Fi', 'Fantasy', 'Documentary', 'Children', 'Crime', 'Film-Noir', 'Thriller', 'Action', 'Western', 'IMAX', 'Romance', '(no genres listed)', 'Animation', 'Horror', 'Mystery', 'War', 'Musical', 'Comedy', 'Adventure'}

# %%
unique_genre.remove('')
print(unique_genre)
# Out:
# {'Drama', 'Sci-Fi', 'Fantasy', 'Documentary', 'Children', 'Crime', 'Film-Noir', 'Thriller', 'Action', 'Western', 'IMAX', 'Romance', '(no genres listed)', 'Animation', 'Horror', 'Mystery', 'War', 'Musical', 'Comedy', 'Adventure'}

# %%
movies_df[(movies_df['genres'] == '') | (movies_df['genres'] == r'\|')]
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres, release_year]
# Index: []

# %%
indices_to_drop = movies_df[movies_df['genres'] == '(no genres listed)|'].index

movies_df = movies_df.drop(indices_to_drop)
movies_df.shape
# Out:
# (9704, 4)

# %%
movies_new = movies_df.reset_index(drop = True)

# %%
unique_genre.remove('(no genres listed)')
print(unique_genre)
# Out:
# {'Drama', 'Sci-Fi', 'Fantasy', 'Documentary', 'Children', 'Crime', 'Film-Noir', 'Thriller', 'Action', 'Western', 'IMAX', 'Romance', 'Animation', 'Horror', 'Mystery', 'War', 'Musical', 'Comedy', 'Adventure'}

# %%
movies_new.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                          genres  release_year
# 0  Adventure|Animation|Children|Comedy|Fantasy|          1995
# 1                   Adventure|Children|Fantasy|          1995
# 2                               Comedy|Romance|          1995
# 3                         Comedy|Drama|Romance|          1995
# 4                                       Comedy|          1995

# %%
genre_list = sorted(list(unique_genre))
print(genre_list, len(genre_list))
# Out:
# ['Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'] 19

# %%
movies_new['genres'] = movies_new['genres'].str[:-1]
movies_new.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  release_year
# 0  Adventure|Animation|Children|Comedy|Fantasy          1995
# 1                   Adventure|Children|Fantasy          1995
# 2                               Comedy|Romance          1995
# 3                         Comedy|Drama|Romance          1995
# 4                                       Comedy          1995

# %%
movies_new = movies_new.merge(weighted_ratings, on = 'movieId', how = 'left')
movies_new.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  release_year  weighted_rating
# 0  Adventure|Animation|Children|Comedy|Fantasy          1995         3.904080
# 1                   Adventure|Children|Fantasy          1995         3.437093
# 2                               Comedy|Romance          1995         3.295312
# 3                         Comedy|Drama|Romance          1995         3.000876
# 4                                       Comedy          1995         3.138173

# %%
movies_new.to_csv(r'C:\Users\ditri\Desktop\Important\Data\Movie Lens Data\ml-latest-small\movie_list_content_based.csv', index = False)

# %%
movies_new['genres'] = movies_new['genres'].str.split(r'\|')
movies_new.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres  release_year  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]          1995
# 1                     [Adventure, Children, Fantasy]          1995
# 2                                  [Comedy, Romance]          1995
# 3                           [Comedy, Drama, Romance]          1995
# 4                                           [Comedy]          1995
#
#    weighted_rating
# 0         3.904080
# 1         3.437093
# 2         3.295312
# 3         3.000876
# 4         3.138173

# %%
n = movies_new.shape[0]

# %%
arr = np.zeros((n, len(genre_list)))

# %%
movies_new['genre_index'] = movies_new['genres'].apply(lambda x : [genre_list.index(element) for element in x])

# %%
movies_new
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9699   193581  Black Butler: Book of the Atlantic (2017)
# 9700   193583               No Game No Life: Zero (2017)
# 9701   193585                               Flint (2017)
# 9702   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9703   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                                  genres  release_year  \
# 0     [Adventure, Animation, Children, Comedy, Fantasy]          1995
# 1                        [Adventure, Children, Fantasy]          1995
# ...
